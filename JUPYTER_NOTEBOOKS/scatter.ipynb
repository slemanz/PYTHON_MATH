# %% [markdown]
# # Scatter Plot
#
# A scatter plot can give us a first indication of the existence of any correlation between two sets of numbers. To create a scatter plot:

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [2, 4, 6 , 8]

plt.scatter(x, y)
plt.show()
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %% [markdown]
# Let's considers four different data sets with identical statistical properties: mean, variance, and correla-
# tion coefficient.

# %%
import matplotlib.gridspec as gridspec

# data set A
x1 = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y1 = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]

# data set B
x2 = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y2 = [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.1, 9.13, 7.26, 4.74]

# data set C
x3 = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y3 = [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73]

# data set D
x4 = [8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8]
y4 = [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.5, 5.56, 7.91, 6.89]

fig = plt.figure(figsize=[16,9], dpi=120, facecolor=(1,1,1))
gs = gridspec.GridSpec(2,2)

ax0 = fig.add_subplot(gs[0,0], facecolor=(0.9,0.9,0.9))
ax1 = fig.add_subplot(gs[0,1], facecolor=(0.9,0.9,0.9))
ax2 = fig.add_subplot(gs[1,0], facecolor=(0.9,0.9,0.9))
ax3 = fig.add_subplot(gs[1,1], facecolor=(0.9,0.9,0.9))

ax0.scatter(x1, y1)
ax1.scatter(x2, y2)
ax2.scatter(x3, y3)
ax3.scatter(x4, y4)

plt.show()

# %% [markdown]
# If we look at just the traditional statistical measures like the mean, standard deviation, and correlation coefficient—these data sets seem nearly identical. But the scatter plots show that these data sets are actually quite different from each other. Thus, scatter plots can be an important tool and should be used alongside other statistical measures before drawing any conclusions about a data set.
#
# ---
#
# [Describing Data with Statistics](statistics.ipynb)
#
# [Main Page](../README.md)
